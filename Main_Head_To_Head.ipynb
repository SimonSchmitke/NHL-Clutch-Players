# %%
from Main import head_to_head_main
head_to_head_main()
# Out:
# Functions_File.py Loaded
#     team_id     shortName        teamName
# 17       24       Anaheim           Ducks
# 31       53       Arizona         Coyotes
# 32       52       Atlanta       Thrashers
# 4         6        Boston          Bruins
# 22        7       Buffalo          Sabres
# 23       20       Calgary          Flames
# 30       12      Carolina      Hurricanes
# 11       16       Chicago      Blackhawks
# 24       21      Colorado       Avalanche
# 26       29      Columbus    Blue Jackets
# 25       25        Dallas           Stars
# 7        17       Detroit       Red Wings
# 28       22      Edmonton          Oilers
# 21       13       Florida        Panthers
# 2        26   Los Angeles           Kings
# 14       30     Minnesota            Wild
# 13        8      Montreal       Canadiens
# 19        2  NY Islanders       Islanders
# 5         3    NY Rangers         Rangers
# 9        18     Nashville       Predators
# 0         1    New Jersey          Devils
# ...
